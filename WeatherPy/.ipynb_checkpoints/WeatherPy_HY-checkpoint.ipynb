# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# <b>Analysis based on Information Dated December 2020</b>
# <br> What's the weather like as we approach the equator?
# <li><b> Trend 1 </b>: Sample cities near the equator are likely to have higher maximum temperature (between 70 and 90 degrees). Sample cities between -20 and 20 latitudes are likely to have higher maximum temperatures than those that are not. Sample cities are more likely to have lower maximum temperature as (1) latitude decreases from -20 and (2) latitude increases from 20. </li>
# <li><b> Trend 2 </b>: There seems to be little correlation between cloudiness and windspeed and distance from the equator (i.e., latitude) for the sample cities. Also note that sample cities' wind speed seem to be concentrated between 0 and 10 mph.</li>
# <li><b> Trend 3 </b>: Sample cities near the equator are likely to have higher humidity (between 60 and 100%). Also note that sample cities between 40 and 80 latitude tend to have high humidity (between 70% and 100%).</li>

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create DataFrame
cities_df = pd.DataFrame({"City": cities})

# Create columns in DataFrame
cities_df["Cloudiness"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
cities_df["Humidity"] = ""
cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Wind Speed"] = ""

print("Beginning Data Retrieval")
print ("--------------------------------")
#set counters for printing status
counter = 1
max_counter = len(cities_df["City"])

# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}

# Loop through the cities_df and run a search for each city for the columns
for index, row in cities_df.iterrows():
    city = row['City']
    print(f"Processing Record {counter} of {max_counter} | {city}")
    counter = counter + 1
    try:
        current_weather = owm.get_current(city, **settings)
        cities_df.loc[index, "Cloudiness"] = current_weather['clouds']['all']
        cities_df.loc[index, "Country"] = current_weather['sys']['country']
        cities_df.loc[index, "Date"] = current_weather['dt']
        cities_df.loc[index, "Humidity"] = current_weather['main']['humidity']
        cities_df.loc[index, "Lat"] = current_weather['coord']['lat']
        cities_df.loc[index, "Lng"] = current_weather['coord']['lon']
        cities_df.loc[index, "Max Temp"] = current_weather['main']["temp_max"]
        cities_df.loc[index, "Wind Speed"] = current_weather['wind']["speed"]        
    except:
        print ("City not found. Skipping...")
    
    time.sleep(0.5)
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of 624 | gilbues
# Processing Record 2 of 624 | port pirie
# Processing Record 3 of 624 | saldanha
# Processing Record 4 of 624 | port alfred
# Processing Record 5 of 624 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 6 of 624 | rikitea
# Processing Record 7 of 624 | peniche
# Processing Record 8 of 624 | punta arenas
# Processing Record 9 of 624 | huntsville
# Processing Record 10 of 624 | colares
# Processing Record 11 of 624 | bara
# Processing Record 12 of 624 | kencong
# Processing Record 13 of 624 | san jeronimo
# Processing Record 14 of 624 | lima
# Processing Record 15 of 624 | camacha
# Processing Record 16 of 624 | pevek
# Processing Record 17 of 624 | castro
# Processing Record 18 of 624 | hilo
# Processing Record 19 of 624 | busselton
# Processing Record 20 of 624 | severo-kurilsk
# Processing Record 21 of 624 | staropesterevo
# Processing Record 22 of 624 | tortoli
# Processing Record 23 of 624 | avarua
# Processing Record 24 of 624 | luba
# Processing Record 25 of 624 | dikson
# Processing Record 26 of 624 | constitucion
# Processing Record 27 of 624 | yellowknife
# Processing Record 28 of 624 | ushuaia
# Processing Record 29 of 624 | arraial do cabo
# Processing Record 30 of 624 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of 624 | litovko
# Processing Record 32 of 624 | manzhouli
# Processing Record 33 of 624 | bambous virieux
# Processing Record 34 of 624 | atuona
# Processing Record 35 of 624 | praia da vitoria
# Processing Record 36 of 624 | beyneu
# Processing Record 37 of 624 | labuhan
# Processing Record 38 of 624 | khatanga
# Processing Record 39 of 624 | roros
# Processing Record 40 of 624 | road town
# Processing Record 41 of 624 | ibra
# Processing Record 42 of 624 | ponta do sol
# Processing Record 43 of 624 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of 624 | nikolskoye
# Processing Record 45 of 624 | luderitz
# Processing Record 46 of 624 | tezu
# Processing Record 47 of 624 | jamestown
# Processing Record 48 of 624 | vaini
# Processing Record 49 of 624 | tiznit
# Processing Record 50 of 624 | bengkulu
# City not found. Skipping...
# Processing Record 51 of 624 | victoria
# Processing Record 52 of 624 | mataura
# Processing Record 53 of 624 | samusu
# City not found. Skipping...
# Processing Record 54 of 624 | ouahigouya
# Processing Record 55 of 624 | barrow
# Processing Record 56 of 624 | mnogovershinnyy
# Processing Record 57 of 624 | taolanaro
# City not found. Skipping...
# Processing Record 58 of 624 | cocula
# Processing Record 59 of 624 | airai
# Processing Record 60 of 624 | gornopravdinsk
# Processing Record 61 of 624 | hermanus
# Processing Record 62 of 624 | cape town
# Processing Record 63 of 624 | veseloyarsk
# Processing Record 64 of 624 | la ronge
# Processing Record 65 of 624 | saleaula
# City not found. Skipping...
# Processing Record 66 of 624 | tromso
# Processing Record 67 of 624 | presidencia roque saenz pena
# Processing Record 68 of 624 | nguruka
# Processing Record 69 of 624 | sobolevo
# Processing Record 70 of 624 | albany
# Processing Record 71 of 624 | chimore
# Processing Record 72 of 624 | puerto ayora
# Processing Record 73 of 624 | belushya guba
# City not found. Skipping...
# Processing Record 74 of 624 | katsuura
# Processing Record 75 of 624 | pyaozerskiy
# Processing Record 76 of 624 | hithadhoo
# Processing Record 77 of 624 | kapaa
# Processing Record 78 of 624 | panaba
# Processing Record 79 of 624 | moose factory
# Processing Record 80 of 624 | pipar
# City not found. Skipping...
# Processing Record 81 of 624 | pirgos
# Processing Record 82 of 624 | ahipara
# Processing Record 83 of 624 | padang
# Processing Record 84 of 624 | broken hill
# Processing Record 85 of 624 | santa rosa
# Processing Record 86 of 624 | utiroa
# City not found. Skipping...
# Processing Record 87 of 624 | odweyne
# City not found. Skipping...
# Processing Record 88 of 624 | aulnoye-aymeries
# Processing Record 89 of 624 | pisco
# Processing Record 90 of 624 | otradnoye
# Processing Record 91 of 624 | mount gambier
# Processing Record 92 of 624 | tuktoyaktuk
# Processing Record 93 of 624 | teahupoo
# Processing Record 94 of 624 | qaanaaq
# Processing Record 95 of 624 | olafsvik
# City not found. Skipping...
# Processing Record 96 of 624 | tautira
# Processing Record 97 of 624 | new norfolk
# Processing Record 98 of 624 | fairbanks
# Processing Record 99 of 624 | alofi
# Processing Record 100 of 624 | hobart
# Processing Record 101 of 624 | grindavik
# Processing Record 102 of 624 | zhanaozen
# Processing Record 103 of 624 | pacific grove
# Processing Record 104 of 624 | kodiak
# Processing Record 105 of 624 | nizhneyansk
# City not found. Skipping...
# Processing Record 106 of 624 | bluff
# Processing Record 107 of 624 | chokurdakh
# Processing Record 108 of 624 | coetupo
# City not found. Skipping...
# Processing Record 109 of 624 | sangmelima
# Processing Record 110 of 624 | vardo
# Processing Record 111 of 624 | amderma
# City not found. Skipping...
# Processing Record 112 of 624 | mikhaylovskoye
# Processing Record 113 of 624 | taoudenni
# Processing Record 114 of 624 | port lincoln
# Processing Record 115 of 624 | avera
# Processing Record 116 of 624 | mahebourg
# Processing Record 117 of 624 | inhambane
# Processing Record 118 of 624 | georgetown
# Processing Record 119 of 624 | andros town
# Processing Record 120 of 624 | kenai
# Processing Record 121 of 624 | meulaboh
# Processing Record 122 of 624 | kattivakkam
# Processing Record 123 of 624 | dingle
# Processing Record 124 of 624 | killybegs
# Processing Record 125 of 624 | kavieng
# Processing Record 126 of 624 | lata
# Processing Record 127 of 624 | san cristobal
# Processing Record 128 of 624 | saint george
# Processing Record 129 of 624 | sur
# Processing Record 130 of 624 | geresk
# City not found. Skipping...
# Processing Record 131 of 624 | butaritari
# Processing Record 132 of 624 | saskylakh
# Processing Record 133 of 624 | zhigansk
# Processing Record 134 of 624 | nyakabindi
# Processing Record 135 of 624 | faanui
# Processing Record 136 of 624 | tateyama
# Processing Record 137 of 624 | gamba
# Processing Record 138 of 624 | nicoya
# Processing Record 139 of 624 | ribeira grande
# Processing Record 140 of 624 | saint-philippe
# Processing Record 141 of 624 | rawson
# Processing Record 142 of 624 | zeya
# Processing Record 143 of 624 | esperance
# Processing Record 144 of 624 | olecko
# Processing Record 145 of 624 | bethel
# Processing Record 146 of 624 | asau
# City not found. Skipping...
# Processing Record 147 of 624 | santa cruz de la palma
# Processing Record 148 of 624 | kuryk
# Processing Record 149 of 624 | bahar
# Processing Record 150 of 624 | high level
# Processing Record 151 of 624 | necochea
# Processing Record 152 of 624 | nanortalik
# Processing Record 153 of 624 | sitka
# Processing Record 154 of 624 | westport
# Processing Record 155 of 624 | waipawa
# Processing Record 156 of 624 | escanaba
# Processing Record 157 of 624 | coquimbo
# Processing Record 158 of 624 | rio tercero
# Processing Record 159 of 624 | elat
# Processing Record 160 of 624 | nandi
# Processing Record 161 of 624 | mabamba
# Processing Record 162 of 624 | plettenberg bay
# Processing Record 163 of 624 | lebu
# Processing Record 164 of 624 | moron
# Processing Record 165 of 624 | sentyabrskiy
# City not found. Skipping...
# Processing Record 166 of 624 | ancud
# Processing Record 167 of 624 | laufen
# Processing Record 168 of 624 | mar del plata
# Processing Record 169 of 624 | brora
# Processing Record 170 of 624 | dunn
# Processing Record 171 of 624 | jizan
# Processing Record 172 of 624 | samana
# Processing Record 173 of 624 | cherskiy
# Processing Record 174 of 624 | port blair
# Processing Record 175 of 624 | bredasdorp
# Processing Record 176 of 624 | east london
# Processing Record 177 of 624 | ambovombe
# Processing Record 178 of 624 | asfi
# City not found. Skipping...
# Processing Record 179 of 624 | azare
# Processing Record 180 of 624 | college
# Processing Record 181 of 624 | carnarvon
# Processing Record 182 of 624 | vidim
# Processing Record 183 of 624 | wilmington
# Processing Record 184 of 624 | broome
# Processing Record 185 of 624 | agara
# Processing Record 186 of 624 | kutum
# Processing Record 187 of 624 | mys shmidta
# City not found. Skipping...
# Processing Record 188 of 624 | amboise
# Processing Record 189 of 624 | chuy
# Processing Record 190 of 624 | barentsburg
# City not found. Skipping...
# Processing Record 191 of 624 | clyde river
# Processing Record 192 of 624 | bessonovka
# Processing Record 193 of 624 | kibala
# Processing Record 194 of 624 | honningsvag
# Processing Record 195 of 624 | chittaurgarh
# Processing Record 196 of 624 | eskil
# Processing Record 197 of 624 | port hardy
# Processing Record 198 of 624 | te anau
# Processing Record 199 of 624 | lumbog
# Processing Record 200 of 624 | ust-ishim
# Processing Record 201 of 624 | stornoway
# City not found. Skipping...
# Processing Record 202 of 624 | eskisehir
# Processing Record 203 of 624 | rameswaram
# Processing Record 204 of 624 | sotouboua
# Processing Record 205 of 624 | tura
# Processing Record 206 of 624 | khani
# Processing Record 207 of 624 | zlatoustovsk
# City not found. Skipping...
# Processing Record 208 of 624 | leningradskiy
# Processing Record 209 of 624 | guerrero negro
# Processing Record 210 of 624 | harper
# Processing Record 211 of 624 | marion
# Processing Record 212 of 624 | genhe
# Processing Record 213 of 624 | port elizabeth
# Processing Record 214 of 624 | taltal
# Processing Record 215 of 624 | bantva
# Processing Record 216 of 624 | narsaq
# Processing Record 217 of 624 | kruisfontein
# Processing Record 218 of 624 | nouadhibou
# Processing Record 219 of 624 | saint-pierre
# Processing Record 220 of 624 | thompson
# Processing Record 221 of 624 | yaan
# Processing Record 222 of 624 | vanavara
# Processing Record 223 of 624 | wa
# City not found. Skipping...
# Processing Record 224 of 624 | kysyl-syr
# Processing Record 225 of 624 | craig
# Processing Record 226 of 624 | arlit
# Processing Record 227 of 624 | torbay
# Processing Record 228 of 624 | sibolga
# Processing Record 229 of 624 | shu
# Processing Record 230 of 624 | port hedland
# Processing Record 231 of 624 | namatanai
# Processing Record 232 of 624 | bonavista
# Processing Record 233 of 624 | ostrovnoy
# Processing Record 234 of 624 | nongstoin
# Processing Record 235 of 624 | mogadishu
# Processing Record 236 of 624 | buon me thuot
# City not found. Skipping...
# Processing Record 237 of 624 | ocos
# Processing Record 238 of 624 | ventspils
# Processing Record 239 of 624 | shache
# Processing Record 240 of 624 | vao
# Processing Record 241 of 624 | tongliao
# Processing Record 242 of 624 | husavik
# Processing Record 243 of 624 | ilulissat
# Processing Record 244 of 624 | lavrentiya
# Processing Record 245 of 624 | ellsworth
# Processing Record 246 of 624 | champerico
# Processing Record 247 of 624 | micheweni
# Processing Record 248 of 624 | lehi
# Processing Record 249 of 624 | finschhafen
# Processing Record 250 of 624 | kalmunai
# Processing Record 251 of 624 | lagoa
# Processing Record 252 of 624 | lorengau
# Processing Record 253 of 624 | ascension
# City not found. Skipping...
# Processing Record 254 of 624 | batagay-alyta
# Processing Record 255 of 624 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 256 of 624 | rypefjord
# Processing Record 257 of 624 | brae
# Processing Record 258 of 624 | endicott
# Processing Record 259 of 624 | attawapiskat
# City not found. Skipping...
# Processing Record 260 of 624 | mahajanga
# Processing Record 261 of 624 | pyapon
# Processing Record 262 of 624 | grand river south east
# City not found. Skipping...
# Processing Record 263 of 624 | kutulik
# Processing Record 264 of 624 | souillac
# Processing Record 265 of 624 | singaparna
# Processing Record 266 of 624 | nador
# Processing Record 267 of 624 | doka
# Processing Record 268 of 624 | kalaleh
# Processing Record 269 of 624 | los llanos de aridane
# Processing Record 270 of 624 | baiyin
# Processing Record 271 of 624 | nampula
# Processing Record 272 of 624 | rocha
# Processing Record 273 of 624 | paamiut
# Processing Record 274 of 624 | katangli
# Processing Record 275 of 624 | upernavik
# Processing Record 276 of 624 | wielun
# Processing Record 277 of 624 | maracacume
# Processing Record 278 of 624 | tiksi
# Processing Record 279 of 624 | kahului
# Processing Record 280 of 624 | sao filipe
# Processing Record 281 of 624 | kawalu
# Processing Record 282 of 624 | tombouctou
# Processing Record 283 of 624 | hamilton
# Processing Record 284 of 624 | ondjiva
# Processing Record 285 of 624 | talnakh
# Processing Record 286 of 624 | gazojak
# Processing Record 287 of 624 | arona
# Processing Record 288 of 624 | damnoen saduak
# Processing Record 289 of 624 | touros
# Processing Record 290 of 624 | blagoyevo
# Processing Record 291 of 624 | murgab
# Processing Record 292 of 624 | beloha
# Processing Record 293 of 624 | zhangye
# Processing Record 294 of 624 | isangel
# Processing Record 295 of 624 | itarema
# Processing Record 296 of 624 | qaqortoq
# Processing Record 297 of 624 | adelaide
# Processing Record 298 of 624 | vaitape
# Processing Record 299 of 624 | morant bay
# Processing Record 300 of 624 | farafangana
# Processing Record 301 of 624 | gorom-gorom
# Processing Record 302 of 624 | norman wells
# Processing Record 303 of 624 | solovetskiy
# City not found. Skipping...
# Processing Record 304 of 624 | samarai
# Processing Record 305 of 624 | iqaluit
# Processing Record 306 of 624 | mecca
# Processing Record 307 of 624 | bauta
# Processing Record 308 of 624 | lasa
# Processing Record 309 of 624 | korla
# City not found. Skipping...
# Processing Record 310 of 624 | imbituba
# Processing Record 311 of 624 | pangnirtung
# Processing Record 312 of 624 | aasiaat
# Processing Record 313 of 624 | toma
# Processing Record 314 of 624 | henties bay
# Processing Record 315 of 624 | phra phutthabat
# Processing Record 316 of 624 | turochak
# Processing Record 317 of 624 | longyearbyen
# Processing Record 318 of 624 | provideniya
# Processing Record 319 of 624 | semey
# Processing Record 320 of 624 | codrington
# Processing Record 321 of 624 | tuatapere
# Processing Record 322 of 624 | zhetybay
# City not found. Skipping...
# Processing Record 323 of 624 | sydney
# Processing Record 324 of 624 | wewak
# Processing Record 325 of 624 | sao joao da barra
# Processing Record 326 of 624 | vostok
# Processing Record 327 of 624 | anadyr
# Processing Record 328 of 624 | kamenka
# Processing Record 329 of 624 | tasiilaq
# Processing Record 330 of 624 | marzuq
# Processing Record 331 of 624 | kungurtug
# Processing Record 332 of 624 | sri aman
# Processing Record 333 of 624 | okakarara
# Processing Record 334 of 624 | beringovskiy
# Processing Record 335 of 624 | axim
# Processing Record 336 of 624 | tidore
# City not found. Skipping...
# Processing Record 337 of 624 | berlevag
# Processing Record 338 of 624 | cayenne
# Processing Record 339 of 624 | makakilo city
# Processing Record 340 of 624 | kytlym
# City not found. Skipping...
# Processing Record 341 of 624 | kamenskoye
# City not found. Skipping...
# Processing Record 342 of 624 | doha
# Processing Record 343 of 624 | mazatlan
# Processing Record 344 of 624 | abu zabad
# Processing Record 345 of 624 | komsomolskiy
# Processing Record 346 of 624 | amqui
# Processing Record 347 of 624 | cabo san lucas
# Processing Record 348 of 624 | bahawalpur
# Processing Record 349 of 624 | melendugno
# Processing Record 350 of 624 | durban
# Processing Record 351 of 624 | albina
# Processing Record 352 of 624 | satitoa
# City not found. Skipping...
# Processing Record 353 of 624 | meyungs
# City not found. Skipping...
# Processing Record 354 of 624 | teya
# Processing Record 355 of 624 | bekhtery
# Processing Record 356 of 624 | margate
# Processing Record 357 of 624 | bulembu
# Processing Record 358 of 624 | thanh hoa
# Processing Record 359 of 624 | talagang
# Processing Record 360 of 624 | nizhniy baskunchak
# Processing Record 361 of 624 | warqla
# City not found. Skipping...
# Processing Record 362 of 624 | innisfail
# Processing Record 363 of 624 | hambantota
# Processing Record 364 of 624 | cap malheureux
# Processing Record 365 of 624 | geraldton
# Processing Record 366 of 624 | dryden
# Processing Record 367 of 624 | isabela
# Processing Record 368 of 624 | teguldet
# Processing Record 369 of 624 | palmer
# Processing Record 370 of 624 | sumbawa
# City not found. Skipping...
# Processing Record 371 of 624 | katy
# Processing Record 372 of 624 | vaitupu
# City not found. Skipping...
# Processing Record 373 of 624 | matamoros
# Processing Record 374 of 624 | jasper
# Processing Record 375 of 624 | san lawrenz
# Processing Record 376 of 624 | vila franca do campo
# Processing Record 377 of 624 | galesong
# Processing Record 378 of 624 | princeton
# Processing Record 379 of 624 | richards bay
# Processing Record 380 of 624 | thiruvananthapuram
# Processing Record 381 of 624 | muros
# Processing Record 382 of 624 | kapoeta
# City not found. Skipping...
# Processing Record 383 of 624 | rio gallegos
# Processing Record 384 of 624 | menongue
# Processing Record 385 of 624 | we
# City not found. Skipping...
# Processing Record 386 of 624 | tamworth
# Processing Record 387 of 624 | zonguldak
# Processing Record 388 of 624 | hualmay
# Processing Record 389 of 624 | roma
# Processing Record 390 of 624 | santiago del estero
# Processing Record 391 of 624 | fort nelson
# Processing Record 392 of 624 | conway
# Processing Record 393 of 624 | tulun
# Processing Record 394 of 624 | salalah
# Processing Record 395 of 624 | sorland
# Processing Record 396 of 624 | diffa
# Processing Record 397 of 624 | porto novo
# Processing Record 398 of 624 | quatre cocos
# Processing Record 399 of 624 | wasilla
# Processing Record 400 of 624 | chegdomyn
# Processing Record 401 of 624 | vila velha
# Processing Record 402 of 624 | tibati
# Processing Record 403 of 624 | shihezi
# Processing Record 404 of 624 | cortez
# Processing Record 405 of 624 | denpasar
# Processing Record 406 of 624 | qandala
# Processing Record 407 of 624 | sena madureira
# Processing Record 408 of 624 | ligayan
# Processing Record 409 of 624 | mrirt
# City not found. Skipping...
# Processing Record 410 of 624 | bud
# Processing Record 411 of 624 | faya
# Processing Record 412 of 624 | mwene-ditu
# Processing Record 413 of 624 | bondo
# Processing Record 414 of 624 | zapresic
# Processing Record 415 of 624 | amuntai
# Processing Record 416 of 624 | riyadh
# Processing Record 417 of 624 | north platte
# Processing Record 418 of 624 | nuoro
# Processing Record 419 of 624 | palabuhanratu
# City not found. Skipping...
# Processing Record 420 of 624 | neryungri
# Processing Record 421 of 624 | shiyan
# Processing Record 422 of 624 | lomza
# Processing Record 423 of 624 | yuci
# Processing Record 424 of 624 | tsihombe
# City not found. Skipping...
# Processing Record 425 of 624 | bereda
# Processing Record 426 of 624 | kaitangata
# Processing Record 427 of 624 | akyab
# City not found. Skipping...
# Processing Record 428 of 624 | abu dhabi
# Processing Record 429 of 624 | fortuna
# Processing Record 430 of 624 | umm kaddadah
# Processing Record 431 of 624 | fredericksburg
# Processing Record 432 of 624 | kautokeino
# Processing Record 433 of 624 | yulara
# Processing Record 434 of 624 | uvat
# Processing Record 435 of 624 | chapais
# Processing Record 436 of 624 | spencer
# Processing Record 437 of 624 | ixtapa
# Processing Record 438 of 624 | buriti dos lopes
# Processing Record 439 of 624 | temaraia
# City not found. Skipping...
# Processing Record 440 of 624 | dunedin
# Processing Record 441 of 624 | viedma
# Processing Record 442 of 624 | mattru
# Processing Record 443 of 624 | loei
# Processing Record 444 of 624 | saint paul
# Processing Record 445 of 624 | corinto
# Processing Record 446 of 624 | punta alta
# Processing Record 447 of 624 | praia
# Processing Record 448 of 624 | lhokseumawe
# Processing Record 449 of 624 | iwanai
# Processing Record 450 of 624 | nishihara
# Processing Record 451 of 624 | kondinskoye
# Processing Record 452 of 624 | rantepao
# Processing Record 453 of 624 | swan river
# Processing Record 454 of 624 | saint-joseph
# Processing Record 455 of 624 | kuala lipis
# Processing Record 456 of 624 | barcelona
# Processing Record 457 of 624 | clearlake
# Processing Record 458 of 624 | chico
# Processing Record 459 of 624 | bathsheba
# Processing Record 460 of 624 | klaksvik
# Processing Record 461 of 624 | salinopolis
# Processing Record 462 of 624 | sao francisco de paula
# Processing Record 463 of 624 | that phanom
# Processing Record 464 of 624 | eldorado
# Processing Record 465 of 624 | santa cecilia
# Processing Record 466 of 624 | hofn
# Processing Record 467 of 624 | mosetse
# Processing Record 468 of 624 | brigantine
# Processing Record 469 of 624 | draguignan
# Processing Record 470 of 624 | nelson bay
# Processing Record 471 of 624 | tarudant
# City not found. Skipping...
# Processing Record 472 of 624 | makokou
# Processing Record 473 of 624 | makasar
# Processing Record 474 of 624 | kalianget
# Processing Record 475 of 624 | ryotsu
# Processing Record 476 of 624 | iralaya
# Processing Record 477 of 624 | mehamn
# Processing Record 478 of 624 | coihaique
# Processing Record 479 of 624 | laguna
# Processing Record 480 of 624 | flinders
# Processing Record 481 of 624 | krasnoselkup
# City not found. Skipping...
# Processing Record 482 of 624 | poum
# Processing Record 483 of 624 | raudeberg
# Processing Record 484 of 624 | zhob
# Processing Record 485 of 624 | buchanan
# Processing Record 486 of 624 | voh
# Processing Record 487 of 624 | celestun
# Processing Record 488 of 624 | la romana
# Processing Record 489 of 624 | rio grande
# Processing Record 490 of 624 | dudinka
# Processing Record 491 of 624 | leuteboro
# Processing Record 492 of 624 | olinda
# Processing Record 493 of 624 | gampaha
# Processing Record 494 of 624 | obera
# Processing Record 495 of 624 | tongren
# Processing Record 496 of 624 | sivaki
# Processing Record 497 of 624 | biak
# Processing Record 498 of 624 | la rioja
# Processing Record 499 of 624 | tasbuget
# City not found. Skipping...
# Processing Record 500 of 624 | alice springs
# Processing Record 501 of 624 | barra do garcas
# Processing Record 502 of 624 | roebourne
# Processing Record 503 of 624 | ojinaga
# Processing Record 504 of 624 | pringsewu
# Processing Record 505 of 624 | ierapetra
# Processing Record 506 of 624 | sorong
# Processing Record 507 of 624 | puerto ayacucho
# Processing Record 508 of 624 | najran
# Processing Record 509 of 624 | goundam
# Processing Record 510 of 624 | longlac
# City not found. Skipping...
# Processing Record 511 of 624 | kismayo
# City not found. Skipping...
# Processing Record 512 of 624 | sosnogorsk
# Processing Record 513 of 624 | kuppam
# Processing Record 514 of 624 | aklavik
# Processing Record 515 of 624 | tawkar
# City not found. Skipping...
# Processing Record 516 of 624 | northam
# Processing Record 517 of 624 | havelock
# Processing Record 518 of 624 | alta floresta
# Processing Record 519 of 624 | zemio
# Processing Record 520 of 624 | villaviciosa
# Processing Record 521 of 624 | gobabis
# Processing Record 522 of 624 | mirandopolis
# Processing Record 523 of 624 | manuk mangkaw
# Processing Record 524 of 624 | yar-sale
# Processing Record 525 of 624 | ilo
# Processing Record 526 of 624 | tunduru
# City not found. Skipping...
# Processing Record 527 of 624 | barabai
# Processing Record 528 of 624 | la cruz
# Processing Record 529 of 624 | sampit
# Processing Record 530 of 624 | alipur duar
# City not found. Skipping...
# Processing Record 531 of 624 | cantaura
# Processing Record 532 of 624 | saryozek
# Processing Record 533 of 624 | kharp
# Processing Record 534 of 624 | conde
# Processing Record 535 of 624 | kokopo
# Processing Record 536 of 624 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 537 of 624 | vytegra
# Processing Record 538 of 624 | springbok
# Processing Record 539 of 624 | baracoa
# Processing Record 540 of 624 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 541 of 624 | tecoanapa
# Processing Record 542 of 624 | novoagansk
# Processing Record 543 of 624 | belyy yar
# Processing Record 544 of 624 | lincoln
# Processing Record 545 of 624 | belmonte
# Processing Record 546 of 624 | bhuj
# Processing Record 547 of 624 | agadez
# Processing Record 548 of 624 | cuamba
# Processing Record 549 of 624 | petropavlovsk-kamchatskiy
# Processing Record 550 of 624 | barawe
# City not found. Skipping...
# Processing Record 551 of 624 | louisbourg
# City not found. Skipping...
# Processing Record 552 of 624 | ulaangom
# Processing Record 553 of 624 | polis
# Processing Record 554 of 624 | mandalgovi
# Processing Record 555 of 624 | ambilobe
# Processing Record 556 of 624 | itaituba
# Processing Record 557 of 624 | vila
# Processing Record 558 of 624 | chopda
# Processing Record 559 of 624 | loding
# Processing Record 560 of 624 | kathu
# Processing Record 561 of 624 | okhotsk
# Processing Record 562 of 624 | san isidro
# Processing Record 563 of 624 | bilibino
# Processing Record 564 of 624 | soyo
# Processing Record 565 of 624 | sioux lookout
# Processing Record 566 of 624 | mushie
# Processing Record 567 of 624 | pontal do parana
# Processing Record 568 of 624 | bolgatanga
# Processing Record 569 of 624 | gladstone
# Processing Record 570 of 624 | solnechnyy
# Processing Record 571 of 624 | mrakovo
# Processing Record 572 of 624 | cotonou
# Processing Record 573 of 624 | saint-augustin
# Processing Record 574 of 624 | andevoranto
# City not found. Skipping...
# Processing Record 575 of 624 | mayo
# Processing Record 576 of 624 | wanning
# Processing Record 577 of 624 | acireale
# Processing Record 578 of 624 | kuching
# Processing Record 579 of 624 | centralia
# Processing Record 580 of 624 | puro
# Processing Record 581 of 624 | tocopilla
# Processing Record 582 of 624 | bam
# Processing Record 583 of 624 | belokurikha
# Processing Record 584 of 624 | port keats
# Processing Record 585 of 624 | ostersund
# Processing Record 586 of 624 | umzimvubu
# City not found. Skipping...
# Processing Record 587 of 624 | buta
# Processing Record 588 of 624 | ternate
# Processing Record 589 of 624 | rumphi
# Processing Record 590 of 624 | athmallik
# Processing Record 591 of 624 | kisangani
# Processing Record 592 of 624 | banepa
# Processing Record 593 of 624 | san francisco
# Processing Record 594 of 624 | jacobina
# Processing Record 595 of 624 | oktyabrskoye
# Processing Record 596 of 624 | acarau
# City not found. Skipping...
# Processing Record 597 of 624 | dzhebariki-khaya
# Processing Record 598 of 624 | marcona
# City not found. Skipping...
# Processing Record 599 of 624 | manggar
# Processing Record 600 of 624 | almaznyy
# Processing Record 601 of 624 | joshimath
# Processing Record 602 of 624 | capelinha
# Processing Record 603 of 624 | borova
# Processing Record 604 of 624 | lagos
# Processing Record 605 of 624 | kakrala
# Processing Record 606 of 624 | hauterive
# Processing Record 607 of 624 | poya
# Processing Record 608 of 624 | kaifeng
# Processing Record 609 of 624 | cidreira
# Processing Record 610 of 624 | dalby
# Processing Record 611 of 624 | povenets
# Processing Record 612 of 624 | hirtshals
# Processing Record 613 of 624 | mapiri
# Processing Record 614 of 624 | mwinilunga
# Processing Record 615 of 624 | tilichiki
# Processing Record 616 of 624 | dzidzantun
# Processing Record 617 of 624 | nuuk
# Processing Record 618 of 624 | muzaffarabad
# Processing Record 619 of 624 | boueni
# Processing Record 620 of 624 | kangaatsiaq
# Processing Record 621 of 624 | horsham
# Processing Record 622 of 624 | almaty
# Processing Record 623 of 624 | alenquer
# Processing Record 624 of 624 | turan

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a copy of the data frame
cities_df_clean = cities_df

# clean data frame
cities_df_clean.replace('', np.nan, inplace=True)
cities_df_clean = cities_df_clean.dropna(how='any', inplace=False)
cities_df_clean = cities_df_clean.reset_index(drop = True)
cities_df_clean.count()
# Out:
# City          561
# Cloudiness    561
# Country       561
# Date          561
# Humidity      561
# Lat           561
# Lng           561
# Max Temp      561
# Wind Speed    561
# dtype: int64

# %%
#save to CSV
cities_df_clean.to_csv(output_data_file)

#display data frame
cities_df_clean.head()
# Out:
#           City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0      gilbues        35.0      BR  1.576994e+09      55.0  -9.83  -45.34
# 1   port pirie        85.0      AU  1.576994e+09      28.0 -33.18  138.01
# 2     saldanha        17.0      PT  1.576994e+09      94.0  41.42   -6.55
# 3  port alfred        79.0      ZA  1.576994e+09      75.0 -33.59   26.89
# 4      rikitea       100.0      PF  1.576994e+09      87.0 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     75.33        4.52
# 1     86.00       13.87
# 2     43.97       10.96
# 3     72.00        4.54
# 4     73.47       15.61

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis = cities_df_clean["Lat"]
y_axis = cities_df_clean["Max Temp"]

plt.figure(figsize = [10,5])
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
date_code = cities_df_clean["Date"][0]
date = str(time.strftime("%D", time.localtime(int(date_code))))
title = f"City Latitude vs. Max Temperature ({date})"
plt.title(title, fontsize=14, fontweight="bold")
plt.grid(which = 'major', axis = "both")
plt.xlabel("Latitude")
plt.xlim(-80,80)
plt.ylabel("Max Temperature (F)")

# Save the Figure
plt.tight_layout()
plt.savefig("output_data/MaxTemp_Lat.png")

# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = cities_df_clean["Lat"]
y_axis = cities_df_clean["Humidity"]

plt.figure(figsize = [10,5])
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
date_code = cities_df_clean["Date"][0]
date = str(time.strftime("%D", time.localtime(int(date_code))))
title = f"City Latitude vs.Humidity ({date})"
plt.title(title, fontsize=14, fontweight="bold")
plt.grid(which = 'major', axis = "both")
plt.xlabel("Latitude")
plt.xlim(-80,80)
plt.ylabel("Humidity (%)")

# Save the Figure
plt.tight_layout()
plt.savefig("output_data/Humidity_Lat.png")

# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = cities_df_clean["Lat"]
y_axis = cities_df_clean["Cloudiness"]

plt.figure(figsize = [10,5])
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
date_code = cities_df_clean["Date"][0]
date = str(time.strftime("%D", time.localtime(int(date_code))))
title = f"City Latitude vs.Cloudiness ({date})"
plt.title(title, fontsize=14, fontweight="bold")
plt.grid(which = 'major', axis = "both")
plt.xlabel("Latitude")
plt.xlim(-80,80)
plt.ylabel("Cloudiness (%)")

# Save the Figure
plt.tight_layout()
plt.savefig("output_data/Cloudiness_Lat.png")

# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = cities_df_clean["Lat"]
y_axis = cities_df_clean["Wind Speed"]

plt.figure(figsize = [10,5])
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
date_code = cities_df_clean["Date"][0]
date = str(time.strftime("%D", time.localtime(int(date_code))))
title = f"City Latitude vs.Wind Speed ({date})"
plt.title(title, fontsize=14, fontweight="bold")
plt.grid(which = 'major', axis = "both")
plt.xlabel("Latitude")
plt.xlim(-80,80)
plt.ylabel("Wind Speed (mph)")

# Save the Figure
plt.tight_layout()
plt.savefig("output_data/WindSpeed_Lat.png")

# Show the Figure
plt.show()
